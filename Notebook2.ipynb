# %%
from image_blocks import split_image_into_blocks
from Segmentation import change_shade, random_color, image_segmentation, form_images, overlapping_output
from similarity import get_similarity_with_neighbours
from pathlib import Path
import cv2
import numpy as np
from image_utils import read_image, display_image

# %%
image_name="bottle.jpg"
image_path = str(Path.cwd()/"inputs"/image_name)
image = read_image(image_path=image_path)
image_blocks, image = split_image_into_blocks(image, block_dim=(10, 10), draw_grid=False)
# Out:
# INFO:root:Selected image is f:\custom_image_segmentation\inputs\bottle.jpg
# INFO:root:The dimensions of the image are (800, 600, 3)

# %%
image_blocks.shape
# Out:
# (80, 60)

# %%
s = image_segmentation(image_blocks, color_shading=True, thresh=0.9)

# %%
for row in s:
    for block in row:
        print(block, block.color, end=" ")
    print()
# Out:
# 0-0 (148, 43, 233) 0-1 (125, 36, 198) 0-2 (106, 30, 168) 0-3 (106, 30, 168) 0-4 (90, 25, 142) 0-5 (62, 17, 99) 0-6 (52, 14, 84) 0-7 (52, 14, 84) 0-8 (52, 14, 84) 0-9 (52, 14, 84) 0-10 (52, 14, 84) 0-11 (52, 14, 84) 0-12 (52, 14, 84) 0-13 (44, 11, 71) 0-14 (44, 11, 71) 0-15 (44, 11, 71) 0-16 (44, 11, 71) 0-17 (44, 11, 71) 0-18 (37, 9, 60) 0-19 (37, 9, 60) 0-20 (37, 9, 60) 0-21 (37, 9, 60) 0-22 (37, 9, 60) 0-23 (37, 9, 60) 0-24 (31, 7, 51) 0-25 (26, 5, 43) 0-26 (26, 5, 43) 0-27 (22, 4, 36) 0-28 (22, 4, 36) 0-29 (18, 3, 30) 0-30 (15, 2, 25) 0-31 (15, 2, 25) 0-32 (12, 1, 21) 0-33 (10, 0, 17) 0-34 (8, 0, 14) 0-35 (6, 0, 11) 0-36 (5, 0, 9) 0-37 (4, 0, 7) 0-38 (4, 0, 7) 0-39 (4, 0, 7) 0-40 (4, 0, 7) 0-41 (3, 0, 5) 0-42 (2, 0, 4) 0-43 (1, 0, 3) 0-44 (1, 0, 3) 0-45 (1, 0, 3) 0-46 (0, 0, 2) 0-47 (0, 0, 1) 0-48 (0, 0, 0) 0-49 (0, 0, 0) 0-50 (0, 0, 0) 0-51 (0, 0, 0) 0-52 (0, 0, 0) 0-53 (0, 0, 0) 0-54 (0, 0, 0) 0-55 (0, 0, 0) 0-56 (0, 0, 0) 0-57 (0, 0, 0) 0-58 (0, 0, 0) 0-59 (0, 0, 0)
# ...

# %%
output = form_images(s, change_color=True)
# Out:
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# (10, 10, 3)
# ...

# %%
output.shape
# Out:
# (800, 600, 3)

# %%
cv2.imshow("Output", output)
cv2.waitKey(0)
cv2.destroyAllWindows()
